# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

"""Scrape EPL team stats from FootyStats for a given season"""
url = "https://footystats.org/england/premier-league#"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, "html.parser")


# Find the main league table
table = soup.find("table", class_="full-league-table")
if not table:
    print(f"No table found for season {season}")
    

links = table.find("tbody").find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if "/clubs/" in l]
team_urls = [f"https://footystats.org{l}" for l in links]
team_url = team_urls[0]
data = requests.get(team_url, headers = headers)
data.text
stats = pd.read_html(data.text)
stats = stats[0]
stats
# Out:
# [01/29/26 14:18:06] WARNING  C:\Users\Tataw                                                         ]8;id=299498;file://C:\ProgramData\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=996984;file://C:\ProgramData\anaconda3\Lib\warnings.py#110\110]8;;\
#                              Clarkson\AppData\Local\Temp\ipykernel_31576\1914685653.py:28:
#                              FutureWarning: Passing literal html to 'read_html' is deprecated and
#                              will be removed in a future version. To read from a literal string,
#                              wrap it in a 'StringIO' object.
#                                stats = pd.read_html(data.text)
#                         Stats  Overall  At Home  At Away
# 0                        Wins      65%      75%      55%
# 1                       Draws      22%      17%      27%
# 2                      Losses      13%       8%      18%
# 3              xG For / Match     1.72     1.83     1.61
# 4          xG Against / Match     0.89     0.72     1.08
# 5              Scored / Match     1.83     2.33     1.27
# 6            Conceded / Match     0.74     0.67     0.82
# 7   AVG (Match Goals Average)     2.57        3     2.09
# 8              Clean Sheets %      48%      50%      45%
# 9           Failed to Score %      13%       8%      18%
# 10             Possession AVG      58%      59%      57%
# 11        Shots Taken / Match    14.91    16.25    13.45
# 12      Shots Conversion Rate      12%      14%       9%
# 13    Fouls Committed / Match    10.17     9.83    10.55
# 14     Fouled Against / Match    10.52    11.33     9.64
# 15              Penalties Won  3 in 23  2 in 12  1 in 11
# 16         Penalties Conceded  0 in 23  0 in 12  0 in 11
# 17         Goal Kicks / Match        5     4.42     5.64
# 18          Throw-ins / Match    16.78    17.33    16.18
# 19         Free-Kicks / Match    10.91    11.58    10.18

# %%
stats.columns = ['Stat_Name', 'overall', 'Home', 'Away']
stats
# Out:
#                     Stat_Name  overall     Home     Away
# 0                        Wins      65%      75%      55%
# 1                       Draws      22%      17%      27%
# 2                      Losses      13%       8%      18%
# 3              xG For / Match     1.72     1.83     1.61
# 4          xG Against / Match     0.89     0.72     1.08
# 5              Scored / Match     1.83     2.33     1.27
# 6            Conceded / Match     0.74     0.67     0.82
# 7   AVG (Match Goals Average)     2.57        3     2.09
# 8              Clean Sheets %      48%      50%      45%
# 9           Failed to Score %      13%       8%      18%
# 10             Possession AVG      58%      59%      57%
# 11        Shots Taken / Match    14.91    16.25    13.45
# 12      Shots Conversion Rate      12%      14%       9%
# 13    Fouls Committed / Match    10.17     9.83    10.55
# 14     Fouled Against / Match    10.52    11.33     9.64
# 15              Penalties Won  3 in 23  2 in 12  1 in 11
# 16         Penalties Conceded  0 in 23  0 in 12  0 in 11
# 17         Goal Kicks / Match        5     4.42     5.64
# 18          Throw-ins / Match    16.78    17.33    16.18
# 19         Free-Kicks / Match    10.91    11.58    10.18

# %%
stats = stats.melt(
    id_vars=['Stat_Name'], 
    var_name='Location', 
    value_name='Value'
)
stats
# Out:
#                     Stat_Name Location    Value
# 0                        Wins  overall      65%
# 1                       Draws  overall      22%
# 2                      Losses  overall      13%
# 3              xG For / Match  overall     1.72
# 4          xG Against / Match  overall     0.89
# 5              Scored / Match  overall     1.83
# 6            Conceded / Match  overall     0.74
# 7   AVG (Match Goals Average)  overall     2.57
# 8              Clean Sheets %  overall      48%
# 9           Failed to Score %  overall      13%
# 10             Possession AVG  overall      58%
# 11        Shots Taken / Match  overall    14.91
# 12      Shots Conversion Rate  overall      12%
# 13    Fouls Committed / Match  overall    10.17
# 14     Fouled Against / Match  overall    10.52
# 15              Penalties Won  overall  3 in 23
# 16         Penalties Conceded  overall  0 in 23
# 17         Goal Kicks / Match  overall        5
# 18          Throw-ins / Match  overall    16.78
# 19         Free-Kicks / Match  overall    10.91
# 20                       Wins     Home      75%
# 21                      Draws     Home      17%
# 22                     Losses     Home       8%
# 23             xG For / Match     Home     1.83
# 24         xG Against / Match     Home     0.72
# 25             Scored / Match     Home     2.33
# 26           Conceded / Match     Home     0.67
# 27  AVG (Match Goals Average)     Home        3
# 28             Clean Sheets %     Home      50%
# 29          Failed to Score %     Home       8%
# 30             Possession AVG     Home      59%
# 31        Shots Taken / Match     Home    16.25
# 32      Shots Conversion Rate     Home      14%
# 33    Fouls Committed / Match     Home     9.83
# 34     Fouled Against / Match     Home    11.33
# 35              Penalties Won     Home  2 in 12
# 36         Penalties Conceded     Home  0 in 12
# 37         Goal Kicks / Match     Home     4.42
# 38          Throw-ins / Match     Home    17.33
# 39         Free-Kicks / Match     Home    11.58
# 40                       Wins     Away      55%
# 41                      Draws     Away      27%
# 42                     Losses     Away      18%
# 43             xG For / Match     Away     1.61
# 44         xG Against / Match     Away     1.08
# 45             Scored / Match     Away     1.27
# 46           Conceded / Match     Away     0.82
# 47  AVG (Match Goals Average)     Away     2.09
# 48             Clean Sheets %     Away      45%
# 49          Failed to Score %     Away      18%
# 50             Possession AVG     Away      57%
# 51        Shots Taken / Match     Away    13.45
# 52      Shots Conversion Rate     Away       9%
# 53    Fouls Committed / Match     Away    10.55
# 54     Fouled Against / Match     Away     9.64
# 55              Penalties Won     Away  1 in 11
# 56         Penalties Conceded     Away  0 in 11
# 57         Goal Kicks / Match     Away     5.64
# 58          Throw-ins / Match     Away    16.18
# 59         Free-Kicks / Match     Away    10.18

# %%
stats_long['Combined_Name'] = stats_long['Location'] + ' ' + stats_long['Stat_Name']
stats_long
# Out:
#                     Stat_Name Location    Value  \
# 0                        Wins  overall      65%
# 1                       Draws  overall      22%
# 2                      Losses  overall      13%
# 3              xG For / Match  overall     1.72
# 4          xG Against / Match  overall     0.89
# 5              Scored / Match  overall     1.83
# 6            Conceded / Match  overall     0.74
# 7   AVG (Match Goals Average)  overall     2.57
# 8              Clean Sheets %  overall      48%
# 9           Failed to Score %  overall      13%
# 10             Possession AVG  overall      58%
# 11        Shots Taken / Match  overall    14.91
# 12      Shots Conversion Rate  overall      12%
# 13    Fouls Committed / Match  overall    10.17
# 14     Fouled Against / Match  overall    10.52
# 15              Penalties Won  overall  3 in 23
# 16         Penalties Conceded  overall  0 in 23
# 17         Goal Kicks / Match  overall        5
# 18          Throw-ins / Match  overall    16.78
# 19         Free-Kicks / Match  overall    10.91
# 20                       Wins     Home      75%
# 21                      Draws     Home      17%
# 22                     Losses     Home       8%
# 23             xG For / Match     Home     1.83
# 24         xG Against / Match     Home     0.72
# 25             Scored / Match     Home     2.33
# 26           Conceded / Match     Home     0.67
# 27  AVG (Match Goals Average)     Home        3
# 28             Clean Sheets %     Home      50%
# 29          Failed to Score %     Home       8%
# 30             Possession AVG     Home      59%
# 31        Shots Taken / Match     Home    16.25
# 32      Shots Conversion Rate     Home      14%
# 33    Fouls Committed / Match     Home     9.83
# 34     Fouled Against / Match     Home    11.33
# 35              Penalties Won     Home  2 in 12
# 36         Penalties Conceded     Home  0 in 12
# 37         Goal Kicks / Match     Home     4.42
# 38          Throw-ins / Match     Home    17.33
# 39         Free-Kicks / Match     Home    11.58
# 40                       Wins     Away      55%
# 41                      Draws     Away      27%
# 42                     Losses     Away      18%
# 43             xG For / Match     Away     1.61
# 44         xG Against / Match     Away     1.08
# 45             Scored / Match     Away     1.27
# 46           Conceded / Match     Away     0.82
# 47  AVG (Match Goals Average)     Away     2.09
# 48             Clean Sheets %     Away      45%
# 49          Failed to Score %     Away      18%
# 50             Possession AVG     Away      57%
# 51        Shots Taken / Match     Away    13.45
# 52      Shots Conversion Rate     Away       9%
# 53    Fouls Committed / Match     Away    10.55
# 54     Fouled Against / Match     Away     9.64
# 55              Penalties Won     Away  1 in 11
# 56         Penalties Conceded     Away  0 in 11
# 57         Goal Kicks / Match     Away     5.64
# 58          Throw-ins / Match     Away    16.18
# 59         Free-Kicks / Match     Away    10.18
#
#                         Combined_Name
# 0                        overall Wins
# 1                       overall Draws
# 2                      overall Losses
# 3              overall xG For / Match
# 4          overall xG Against / Match
# 5              overall Scored / Match
# 6            overall Conceded / Match
# 7   overall AVG (Match Goals Average)
# 8              overall Clean Sheets %
# 9           overall Failed to Score %
# 10             overall Possession AVG
# 11        overall Shots Taken / Match
# 12      overall Shots Conversion Rate
# 13    overall Fouls Committed / Match
# 14     overall Fouled Against / Match
# 15              overall Penalties Won
# 16         overall Penalties Conceded
# 17         overall Goal Kicks / Match
# 18          overall Throw-ins / Match
# 19         overall Free-Kicks / Match
# 20                          Home Wins
# 21                         Home Draws
# 22                        Home Losses
# 23                Home xG For / Match
# 24            Home xG Against / Match
# 25                Home Scored / Match
# 26              Home Conceded / Match
# 27     Home AVG (Match Goals Average)
# 28                Home Clean Sheets %
# 29             Home Failed to Score %
# 30                Home Possession AVG
# 31           Home Shots Taken / Match
# 32         Home Shots Conversion Rate
# 33       Home Fouls Committed / Match
# 34        Home Fouled Against / Match
# 35                 Home Penalties Won
# 36            Home Penalties Conceded
# 37            Home Goal Kicks / Match
# 38             Home Throw-ins / Match
# 39            Home Free-Kicks / Match
# 40                          Away Wins
# 41                         Away Draws
# 42                        Away Losses
# 43                Away xG For / Match
# 44            Away xG Against / Match
# 45                Away Scored / Match
# 46              Away Conceded / Match
# 47     Away AVG (Match Goals Average)
# 48                Away Clean Sheets %
# 49             Away Failed to Score %
# 50                Away Possession AVG
# 51           Away Shots Taken / Match
# 52         Away Shots Conversion Rate
# 53       Away Fouls Committed / Match
# 54        Away Fouled Against / Match
# 55                 Away Penalties Won
# 56            Away Penalties Conceded
# 57            Away Goal Kicks / Match
# 58             Away Throw-ins / Match
# 59            Away Free-Kicks / Match

# %%
stats = stats_long[['Combined_Name', 'Value']].set_index('Combined_Name')
stats
# Out:
#                                      Value
# Combined_Name
# overall Wins                           65%
# overall Draws                          22%
# overall Losses                         13%
# overall xG For / Match                1.72
# overall xG Against / Match            0.89
# overall Scored / Match                1.83
# overall Conceded / Match              0.74
# overall AVG (Match Goals Average)     2.57
# overall Clean Sheets %                 48%
# overall Failed to Score %              13%
# overall Possession AVG                 58%
# overall Shots Taken / Match          14.91
# overall Shots Conversion Rate          12%
# overall Fouls Committed / Match      10.17
# overall Fouled Against / Match       10.52
# overall Penalties Won              3 in 23
# overall Penalties Conceded         0 in 23
# overall Goal Kicks / Match               5
# overall Throw-ins / Match            16.78
# overall Free-Kicks / Match           10.91
# Home Wins                              75%
# Home Draws                             17%
# Home Losses                             8%
# Home xG For / Match                   1.83
# Home xG Against / Match               0.72
# Home Scored / Match                   2.33
# Home Conceded / Match                 0.67
# Home AVG (Match Goals Average)           3
# Home Clean Sheets %                    50%
# Home Failed to Score %                  8%
# Home Possession AVG                    59%
# Home Shots Taken / Match             16.25
# Home Shots Conversion Rate             14%
# Home Fouls Committed / Match          9.83
# Home Fouled Against / Match          11.33
# Home Penalties Won                 2 in 12
# Home Penalties Conceded            0 in 12
# Home Goal Kicks / Match               4.42
# Home Throw-ins / Match               17.33
# Home Free-Kicks / Match              11.58
# Away Wins                              55%
# Away Draws                             27%
# Away Losses                            18%
# Away xG For / Match                   1.61
# Away xG Against / Match               1.08
# Away Scored / Match                   1.27
# Away Conceded / Match                 0.82
# Away AVG (Match Goals Average)        2.09
# Away Clean Sheets %                    45%
# Away Failed to Score %                 18%
# Away Possession AVG                    57%
# Away Shots Taken / Match             13.45
# Away Shots Conversion Rate              9%
# Away Fouls Committed / Match         10.55
# Away Fouled Against / Match           9.64
# Away Penalties Won                 1 in 11
# Away Penalties Conceded            0 in 11
# Away Goal Kicks / Match               5.64
# Away Throw-ins / Match               16.18
# Away Free-Kicks / Match              10.18

# %%
import pandas as pd

# 1. Reset index so 'Combined_Name' becomes a regular column
stats = stats.reset_index()

# 2. Transpose the data
# This makes 'Combined_Name' values become the header row
stats = stats.set_index('Combined_Name').T

# 3. Clean up (Optional)
# If you want to remove the index name 'Combined_Name' for a cleaner look:
stats.columns.name = None

stats
# Out:
#       overall Wins overall Draws overall Losses overall xG For / Match  \
# Value          65%           22%            13%                   1.72
#
#       overall xG Against / Match overall Scored / Match  \
# Value                       0.89                   1.83
#
#       overall Conceded / Match overall AVG (Match Goals Average)  \
# Value                     0.74                              2.57
#
#       overall Clean Sheets % overall Failed to Score %  ...  \
# Value                    48%                       13%  ...
#
#       Away Possession AVG Away Shots Taken / Match Away Shots Conversion Rate  \
# Value                 57%                    13.45                         9%
#
#       Away Fouls Committed / Match Away Fouled Against / Match  \
# Value                        10.55                        9.64
#
#       Away Penalties Won Away Penalties Conceded Away Goal Kicks / Match  \
# Value            1 in 11                 0 in 11                    5.64
#
#       Away Throw-ins / Match Away Free-Kicks / Match
# Value                  16.18                   10.18
#
# [1 rows x 60 columns]

# %%
def scrapeSeason(use_selenium=False):
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd
    import re
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
    }
    
    url = "https://footystats.org/england/premier-league"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    
    # League table (ALWAYS WORKS)
    league_table = soup.find("table", class_="full-league-table")
    rows = league_table.find("tbody").find_all("tr")
    data = []
    
    for row in rows:
        cols = row.find_all("td")
        if len(cols) < 12: continue
            
        team_cell = cols[1].text.strip()
        stats = [col.text.strip() for col in cols]
        
        data.append({
            'Rank': stats[0],
            'Team': team_cell,
            'Played': stats[2],
            'W': stats[3],
            'D': stats[4],
            'L': stats[5],
            'GF': stats[6],
            'GA': stats[7],
            'GD': stats[8],
            'Pts': stats[9],
            'Form': stats[10],
            'PPG': stats[11],
            'ClShts': stats[12] if len(stats) > 12 else '',
            'BTTS': stats[13] if len(stats) > 13 else '',
            'xGF': stats[14] if len(stats) > 14 else ''
        })
    
    df_final = pd.DataFrame(data)
    
    #Save as CSV file
    print(f"✅ Complete EPL table: {len(df_final)} teams")
    filename = f'epl_footystats_{pd.Timestamp.now().strftime("%Y%m%d_%H%M")}.csv'
    df_final.to_csv(filename, index=False)
    print(f"💾 Saved: {filename}")
    
    return df_final

# Use this - works immediately!
df = scrapeSeason()
df
# Out:
# ✅ Complete EPL table: 20 teams
# 💾 Saved: epl_footystats_20260131_2317.csv
#    Rank Team                      Played   W   D   L  GF  GA  GD  Pts Form  \
# 0     1                       Arsenal FC  24  16   5   3  46  17  +29   53
# 1     2               Manchester City FC  23  14   4   5  47  21  +26   46
# 2     3                   Aston Villa FC  23  14   4   5  35  25  +10   46
# 3     4                       Chelsea FC  24  11   7   6  42  27  +15   40
# 4     5             Manchester United FC  23  10   8   5  41  34   +7   38
# 5     6                     Liverpool FC  23  10   6   7  35  32   +3   36
# 6     7                        Fulham FC  23  10   4   9  32  32    0   34
# 7     8                       Everton FC  24   9   7   8  26  27   -1   34
# 8     9              Newcastle United FC  23   9   6   8  32  29   +3   33
# 9    10                     Brentford FC  23  10   3  10  35  32   +3   33
# 10   11                   Sunderland AFC  23   8   9   6  24  26   -2   33
# 11   12                  AFC Bournemouth  24   8   9   7  40  43   -3   33
# 12   13        Brighton & Hove Albion FC  24   7  10   7  34  32   +2   31
# 13   14             Tottenham Hotspur FC  23   7   7   9  33  31   +2   28
# 14   15                Crystal Palace FC  23   7   7   9  24  28   -4   28
# 15   16                  Leeds United FC  24   6   8  10  31  42  -11   26
# 16   17             Nottingham Forest FC  23   7   4  12  23  34  -11   25
# 17   18               West Ham United FC  24   5   5  14  29  48  -19   20
# 18   19                       Burnley FC  23   3   6  14  25  44  -19   15
# 19   20       Wolverhampton Wanderers FC  24   1   5  18  15  45  -30    8
#
#       PPG ClShts BTTS  xGF
# 0   WDDLW   2.21  50%  46%
# 1   DDDLW   2.00  43%  43%
# 2   LWDLW   2.00  30%  52%
# 3   DLWWW   1.67  38%  63%
# 4   DDDWW   1.65  13%  74%
# 5   DDDDL   1.57  30%  61%
# 6   DDWLW   1.48  22%  61%
# 7   LDWDD   1.42  38%  42%
# 8   WWWDL   1.43  30%  57%
# 9   DWWLL   1.43  22%  52%
# 10  DDLWL   1.43  30%  48%
# 11  LWDWW   1.38  25%  67%
# 12  WDDLD   1.29  21%  71%
# 13  DDLLD   1.22  30%  57%
# 14  DLDLL   1.22  35%  48%
# 15  DLWDL   1.08  17%  63%
# 16  LLWDW   1.09  22%  35%
# 17  LLWWL   0.83   4%  63%
# 18  LLDDD   0.65  13%  61%
# 19  WDDLL   0.33   8%  42%
